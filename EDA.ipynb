# %%
# %pip install -r requirements.txt
# Out:
# Requirement already satisfied: numpy in /home/vlaght/miniconda3/envs/notebooks/lib/python3.10/site-packages (from -r requirements.txt (line 1)) (1.26.4)
# Requirement already satisfied: pandas in /home/vlaght/miniconda3/envs/notebooks/lib/python3.10/site-packages (from -r requirements.txt (line 2)) (1.5.3)
# Requirement already satisfied: matplotlib in /home/vlaght/miniconda3/envs/notebooks/lib/python3.10/site-packages (from -r requirements.txt (line 3)) (3.10.0)
# Requirement already satisfied: seaborn in /home/vlaght/miniconda3/envs/notebooks/lib/python3.10/site-packages (from -r requirements.txt (line 4)) (0.13.2)
# Requirement already satisfied: plotly in /home/vlaght/miniconda3/envs/notebooks/lib/python3.10/site-packages (from -r requirements.txt (line 5)) (6.0.0)
# Requirement already satisfied: scikit-learn in /home/vlaght/miniconda3/envs/notebooks/lib/python3.10/site-packages (from -r requirements.txt (line 6)) (1.6.1)
# Requirement already satisfied: python-dateutil>=2.8.1 in /home/vlaght/miniconda3/envs/notebooks/lib/python3.10/site-packages (from pandas->-r requirements.txt (line 2)) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /home/vlaght/miniconda3/envs/notebooks/lib/python3.10/site-packages (from pandas->-r requirements.txt (line 2)) (2025.1)
# Requirement already satisfied: contourpy>=1.0.1 in /home/vlaght/miniconda3/envs/notebooks/lib/python3.10/site-packages (from matplotlib->-r requirements.txt (line 3)) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in /home/vlaght/miniconda3/envs/notebooks/lib/python3.10/site-packages (from matplotlib->-r requirements.txt (line 3)) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /home/vlaght/miniconda3/envs/notebooks/lib/python3.10/site-packages (from matplotlib->-r requirements.txt (line 3)) (4.55.8)
# Requirement already satisfied: kiwisolver>=1.3.1 in /home/vlaght/miniconda3/envs/notebooks/lib/python3.10/site-packages (from matplotlib->-r requirements.txt (line 3)) (1.4.8)
# Requirement already satisfied: packaging>=20.0 in /home/vlaght/miniconda3/envs/notebooks/lib/python3.10/site-packages (from matplotlib->-r requirements.txt (line 3)) (24.2)
# Requirement already satisfied: pillow>=8 in /home/vlaght/miniconda3/envs/notebooks/lib/python3.10/site-packages (from matplotlib->-r requirements.txt (line 3)) (11.1.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /home/vlaght/miniconda3/envs/notebooks/lib/python3.10/site-packages (from matplotlib->-r requirements.txt (line 3)) (3.2.1)
# Requirement already satisfied: narwhals>=1.15.1 in /home/vlaght/miniconda3/envs/notebooks/lib/python3.10/site-packages (from plotly->-r requirements.txt (line 5)) (1.25.0)
# Requirement already satisfied: scipy>=1.6.0 in /home/vlaght/miniconda3/envs/notebooks/lib/python3.10/site-packages (from scikit-learn->-r requirements.txt (line 6)) (1.15.1)
# Requirement already satisfied: joblib>=1.2.0 in /home/vlaght/miniconda3/envs/notebooks/lib/python3.10/site-packages (from scikit-learn->-r requirements.txt (line 6)) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /home/vlaght/miniconda3/envs/notebooks/lib/python3.10/site-packages (from scikit-learn->-r requirements.txt (line 6)) (3.5.0)
# Requirement already satisfied: six>=1.5 in /home/vlaght/miniconda3/envs/notebooks/lib/python3.10/site-packages (from python-dateutil>=2.8.1->pandas->-r requirements.txt (line 2)) (1.17.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
dataset_path = "dataset_raw.csv"

# %%
import pandas as pd
import numpy as np
import seaborn as sns
from pathlib import Path

df = pd.read_csv(Path(dataset_path))
df.head()
# Out:
#    gender   age  hypertension  heart_disease smoking_history    bmi  \
# 0  Female  80.0             0              1           never  25.19
# 1  Female  54.0             0              0         No Info  27.32
# 2    Male  28.0             0              0           never  27.32
# 3  Female  36.0             0              0         current  23.45
# 4    Male  76.0             1              1         current  20.14
#
#    HbA1c_level  blood_glucose_level  diabetes
# 0          6.6                  140         0
# 1          6.6                   80         0
# 2          5.7                  158         0
# 3          5.0                  155         0
# 4          4.8                  155         0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100000 entries, 0 to 99999
# Data columns (total 9 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   gender               100000 non-null  object
#  1   age                  100000 non-null  float64
#  2   hypertension         100000 non-null  int64
#  3   heart_disease        100000 non-null  int64
#  4   smoking_history      100000 non-null  object
#  5   bmi                  100000 non-null  float64
#  6   HbA1c_level          100000 non-null  float64
#  7   blood_glucose_level  100000 non-null  int64
#  8   diabetes             100000 non-null  int64
# dtypes: float64(3), int64(4), object(2)
# memory usage: 6.9+ MB

# %%
# Looking for null values
df.isnull().sum()
# Out:
# gender                 0
# age                    0
# hypertension           0
# heart_disease          0
# smoking_history        0
# bmi                    0
# HbA1c_level            0
# blood_glucose_level    0
# diabetes               0
# dtype: int64

# %%
#  let's look closer at non-numeric columns as they are low-hanging fruit
df.gender.unique()
# we can see that there is 'Other' value in this field, which is a non-biological;
# it will certainly lower our accuracy, but let's remap it to numeric value 2,
# whereas female would be 0 (because of my personal belief in women importance) and
# male will be 1
# Out:
# array(['Female', 'Male', 'Other'], dtype=object)

# %%
df.smoking_history.unique()
# we can see quite vague values such as 'former', 'ever', 'not current';
# I'll try to give em numerical values and we will see if that will affect our data.
# Also, I've googled that smoking actually affects diabetes according to the medicine science,
# so I think it is important to embed this data as a feature
# Out:
# array(['never', 'No Info', 'current', 'former', 'ever', 'not current'],
#       dtype=object)

# %%
# let's remap several columns to a machine-processable format
SMOKING_HISTORY_REMAPPING = {
    'never': 0,
    'No Info': 0, # this value came to me after initially using 1, since a lot of kids have No Info
    'former': 2,
    'not current': 3,
    'current': 4,
    'ever': 4,
}
df['smoking_history'] = df['smoking_history'].map(SMOKING_HISTORY_REMAPPING)

GENDER_REMAPPING = {
    'Female': 0,
    'Male': 1,
    'Other': 2,
}
df['gender'] = df['gender'].map(GENDER_REMAPPING)
df['smoking_history'] = df['smoking_history'].astype(int)
df['gender'] = df['gender'].astype(int)

# %%
# Maybe there are duplicates?
df.duplicated().sum()
# Out:
# 5891

# %%
# luckily, there is a fancy method for this
df = df.drop_duplicates()

# %%
# now we should refer to common sence when inspecting other columns
df.bmi.describe()
# no zero values for BMI as it should be, ok
# Out:
# count    94109.000000
# mean        27.321978
# std          6.840092
# min         10.010000
# 25%         23.280000
# 50%         27.320000
# 75%         30.000000
# max         95.690000
# Name: bmi, dtype: float64

# %%
df.age.describe()
# I guess the minimum value for 0.08 could be ok, but lets inspect this row closer
# Out:
# count    94109.000000
# mean        41.783242
# std         22.509183
# min          0.080000
# 25%         24.000000
# 50%         43.000000
# 75%         60.000000
# max         80.000000
# Name: age, dtype: float64

# %%
df[df.age == 0.08]
# well, there are a lot of results, and these look OK to me
# Out:
#        gender   age  hypertension  heart_disease  smoking_history    bmi  \
# 155         0  0.08             0              0                0  14.43
# 2049        0  0.08             0              0                0  13.35
# 3742        1  0.08             0              0                0  12.80
# 9683        0  0.08             0              0                0  11.88
# 13162       1  0.08             0              0                0  27.32
# 16028       1  0.08             0              0                0  14.40
# 29551       1  0.08             0              0                0  13.55
# 30060       1  0.08             0              0                0  12.89
# 32402       1  0.08             0              0                0  13.68
# 33684       1  0.08             0              0                0  30.64
# 34663       1  0.08             0              0                0  27.32
# 38883       1  0.08             0              0                0  14.92
# 40039       0  0.08             0              0                0  14.26
# 45073       1  0.08             0              0                0  11.10
# 46033       0  0.08             0              0                0  14.10
# 48070       0  0.08             0              0                0  12.22
# 48181       0  0.08             0              0                0  27.32
# 53735       1  0.08             0              0                0  12.08
# 53946       1  0.08             0              0                0  27.32
# 54651       1  0.08             0              0                0  12.29
# 57276       0  0.08             0              0                0  27.32
# 57655       0  0.08             0              0                0  12.82
# 63095       0  0.08             0              0                0  13.39
# 63616       1  0.08             0              0                0  13.45
# 67326       1  0.08             0              0                0  11.05
# 78087       0  0.08             0              0                0  13.03
# 79692       1  0.08             0              0                0  27.32
# 81186       0  0.08             0              0                0  12.77
# 84041       1  0.08             0              0                0  15.98
# 84702       0  0.08             0              0                0  27.32
# 86802       0  0.08             0              0                0  27.32
# 92964       1  0.08             0              0                0  12.10
# 93847       0  0.08             0              0                0  12.74
# 94556       0  0.08             0              0                0  27.32
# 94604       1  0.08             0              0                0  14.73
# 98965       0  0.08             0              0                0  12.50
#
#        HbA1c_level  blood_glucose_level  diabetes
# 155            6.5                  160         0
# 2049           3.5                  145         0
# 3742           6.6                   80         0
# 9683           5.7                   80         0
# 13162          6.1                  126         0
# 16028          6.0                   90         0
# 29551          6.1                  145         0
# 30060          6.5                  145         0
# 32402          5.0                   85         0
# 33684          6.6                  130         0
# 34663          5.8                  155         0
# 38883          3.5                   90         0
# 40039          6.5                  160         0
# 45073          6.1                   80         0
# 46033          5.0                  160         0
# 48070          3.5                  130         0
# 48181          4.5                  160         0
# 53735          6.2                  158         0
# 53946          5.8                  200         0
# 54651          5.8                  140         0
# 57276          3.5                  130         0
# 57655          3.5                   90         0
# 63095          6.1                   90         0
# 63616          5.7                  158         0
# 67326          4.5                  200         0
# 78087          6.2                  158         0
# 79692          5.8                  160         0
# 81186          4.5                  160         0
# 84041          6.1                  158         0
# 84702          4.8                  140         0
# 86802          5.0                  155         0
# 92964          6.1                  159         0
# 93847          3.5                  140         0
# 94556          6.5                   90         0
# 94604          3.5                  200         0
# 98965          4.5                  155         0

# %%
df.info()
# now our dataset looks good, let's dump it for further processing
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 94109 entries, 0 to 99999
# Data columns (total 9 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   gender               94109 non-null  int64
#  1   age                  94109 non-null  float64
#  2   hypertension         94109 non-null  int64
#  3   heart_disease        94109 non-null  int64
#  4   smoking_history      94109 non-null  int64
#  5   bmi                  94109 non-null  float64
#  6   HbA1c_level          94109 non-null  float64
#  7   blood_glucose_level  94109 non-null  int64
#  8   diabetes             94109 non-null  int64
# dtypes: float64(3), int64(6)
# memory usage: 7.2 MB

# %%
df.to_csv("dataset.csv")
